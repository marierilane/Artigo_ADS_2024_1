# %%
import os
import psutil
import time
from datetime import datetime
import statistics
import matplotlib.pyplot as plt
import pandas as pd


def plot_graphics(data_pc1, data_pc2, title_pc1, title_pc2):
    df_pc1 = pd.DataFrame(data_pc1)
    df_pc2 = pd.DataFrame(data_pc2)

    # Plotting
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 10))

    # Plot for PC1
    df_pc1.plot(x='Cargas', y=['CPU (%)', 'Memória (%)', 'Disco (%)', 'Swap (%)'], kind='bar', ax=axes[0, 0], title=title_pc1 + ' - Uso de Recursos (%)')
    df_pc1.plot(x='Cargas', y='Timestamp (s)', kind='line', marker='o', ax=axes[0, 1], title=title_pc1 + ' - Tempo de Execução (s)')

    # Plot for PC2
    df_pc2.plot(x='Cargas', y=['CPU (%)', 'Memória (%)', 'Disco (%)', 'Swap (%)'], kind='bar', ax=axes[1, 0], title=title_pc2 + ' - Uso de Recursos (%)')
    df_pc2.plot(x='Cargas', y='Timestamp (s)', kind='line', marker='o', ax=axes[1, 1], title=title_pc2 + ' - Tempo de Execução (s)')

    # Adjust layout
    plt.tight_layout()
    plt.show()

# Data for PC1 - Geração de Código a partir de Diagramas UML
data_pc1_codigos = {
    'Cargas': ['Leve', 'Moderada', 'Pesada'],
    'CPU (%)': [6.5, 16.9, 40.1],
    'Memória (%)': [65.2, 65.0, 67.3],
    'Disco (%)': [94.2, 94.2, 94.2],
    'Swap (%)': [0.6, 1.0, 1.2],
    'Timestamp (s)': [8, 12, 40]
}

# Data for PC2 - Geração de Código a partir de Diagramas UML
data_pc2_codigos = {
    'Cargas': ['Leve', 'Moderada', 'Pesada'],
    'CPU (%)': [43, 56.4, 75.3],
    'Memória (%)': [85.6, 82.4, 88.6],
    'Disco (%)': [79.6, 79.6, 79.6],
    'Swap (%)': [13.0, 14.8, 15.1],
    'Timestamp (s)': [10, 12, 26]
}

# Plotting graphics for Geração de Código a partir de Diagramas UML
plot_graphics(data_pc1_codigos, data_pc2_codigos, 'PC1', 'PC2')

# Data for PC1 - Geração de Diagramas UML a partir de Código
data_pc1_diagramas = {
    'Cargas': ['Leve', 'Moderada', 'Pesada'],
    'CPU (%)': [4.3, 12.9, 58.0],
    'Memória (%)': [54.7, 54.6, 58.0],
    'Disco (%)': [94.2, 94.2, 94.2],
    'Swap (%)': [0.8, 1.3, 1.8],
    'Timestamp (s)': [8, 12, 18]
}

# Data for PC2 - Geração de Diagramas UML a partir de Código
data_pc2_diagramas = {
    'Cargas': ['Leve', 'Moderada', 'Pesada'],
    'CPU (%)': [22.0, 41.0, 71.0],
    'Memória (%)': [60.3, 75.6, 85.4],
    'Disco (%)': [70.1, 75.2, 79.6],
    'Swap (%)': [5.0, 10.0, 14.1],
    'Timestamp (s)': [10, 18, 30]
}

# Plotting graphics for Geração de Diagramas UML a partir de Código
plot_graphics(data_pc1_diagramas, data_pc2_diagramas, 'PC1', 'PC2')

# Summary data for Geração de Código a partir de Diagramas UML
data_summary_codigos = {
    'Métrica': ['CPU (%)', 'Memória (%)', 'Disco (%)', 'Swap (%)', 'Timestamp (s)'],
    'Leve PC1': [6.5, 65.2, 94.2, 0.6, 8],
    'Moderada PC1': [16.9, 65.0, 94.2, 1.0, 12],
    'Pesada PC1': [40.1, 67.3, 94.2, 1.2, 40],
    'Leve PC2': [43, 85.6, 79.6, 13.0, 10],
    'Moderada PC2': [56.4, 82.4, 79.6, 14.8, 12],
    'Pesada PC2': [75.3, 88.6, 79.6, 15.1, 26]
}

df_summary_codigos = pd.DataFrame(data_summary_codigos)

# Summary data for Geração de Diagramas UML a partir de Código
data_summary_diagramas = {
    'Métrica': ['CPU (%)', 'Memória (%)', 'Disco (%)', 'Swap (%)', 'Timestamp (s)'],
    'Leve PC1': [4.3, 54.7, 94.2, 0.8, 8],
    'Moderada PC1': [12.9, 54.6, 94.2, 1.3, 12],
    'Pesada PC1': [58.0, 58.0, 94.2, 1.8, 18],
    'Leve PC2': [22.0, 60.3, 70.1, 5.0, 10],
    'Moderada PC2': [41.0, 75.6, 75.2, 10.0, 18],
    'Pesada PC2': [71.0, 85.4, 79.6, 14.1, 30]
}

df_summary_diagramas = pd.DataFrame(data_summary_diagramas)

import ace_tools as tools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c046e95569d5> in <cell line: 101>()
#      99 df_summary_diagramas = pd.DataFrame(data_summary_diagramas)
#     100
# --> 101 import ace_tools as tools
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
